# %% [markdown]
# # Lists Practice

# %% [markdown]
# ## Library System using Classes
# In this practice, you will create a **Library System** using Python classes. You will define two classes: a **Book** class to represent individual books and a **Library** class to manage a collection of books. The system should allow users to add books, remove books, and display the list of books currently in the library.
#
# ### Task:
# Create a library system using the following steps:
#
# 1. Create a `Book` class:
#
#   - The `Book` class should have two attributes: `title` and `author`.
#   - It should also have a method to return a string representation of the book, showing both the title and the author.
#
# 2. Create a `Library` class:
#
#   - The `Library` class should manage a collection of books (a list of `Book` objects).
#   - The `Library` class should have methods to:
#     - Add a book to the library.
#     - Remove a book by its title.
#     - Display all books currently in the library.
#
# 3. Instantiate multiple `Book` objects:
#
#   - Add at least two books to the library.
#   - Display the library contents.
#   - Remove a book from the library and display the updated list of books.

# %%
# Class representing a Book
class Book:
  def __init__(self, title, author):
    """
    Initializes a book with a title and author.

    Args:
    - title (str): The title of the book.
    - author (str): The author of the book.
    """
    self.title = title
    self.author = author

  def __str__(self):
    """
    String representation of the book.

    Returns:
    - str: The title and author of the book.
    """
    return f"'{self.title}' by {self.author}"

# %%
############### YOUR CODE STARTS HERE ###############
# Class representing a Library
class Library:
  def __init__(self):
    """
    Initializes an empty library.
    """

  def add_book(self, book):
    """
    Adds a book to the library.

    Args:
    - book (Book): The book object to add.
    """

  def remove_book(self, title):
    """
    Removes a book from the library by its title.

    Args:
    - title (str): The title of the book to remove.
    """

  def display_books(self):
    """
    Displays all books in the library.
    """
    if :

    else:
        print("The library is empty.")
################ YOUR CODE ENDS HERE ################

# %%
# Create two book objects
book1 = Book('The Great Gatsby', 'F. Scott Fitzgerald')
book2 = Book('1984', 'George Orwell')

# Create a library object
library = Library()

# Add books to the library
library.add_book(book1)
library.add_book(book2)

# Display books in the library
print("Books currently in the library:")
library.display_books()

# Remove a book
library.remove_book('1984')

# Display books again
print("\nBooks currently in the library after removing '1984':")
library.display_books()
