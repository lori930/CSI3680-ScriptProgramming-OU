# %% [markdown]
# # **OU CSI 3680 Script Programming: Lab 5 (Part II)**

# %% [markdown]
# ## Fetch Current Weather Data
# Write a Python program, to automatically retrieve weather data from the Internet:
# - Read the requested location from the user input
# - Downloads JSON weather data from [OpenWeatherMap.org](https://openweathermap.org/)
# - Convert the string of JSON data to a Python data structure
# - Print the weather for today
# - Save the results into a JSON file, with pretty encoding
#
# Functions you may need:
# - `requests.get()`
# - `json.loads()`

# %% [markdown]
# ### Create your account to obtain an API key
# Before we writing the code, let's make sure we all have the API key on hand. If you don't have one yet, here is what you should do:
#
# 1. Go to [Weather API](https://openweathermap.org/api), click on `sign up`
# 2. Verify your email before obtaining the key
# 3. It may take a few hours to activate your key
# - Your API key is a string code that look something like `30144aba38018987d84710d0e319281e`
# - Free unless you are making more than 60 API calls per minute
# - Keep the API key secret; anyone who knows it can write scripts with your accoun's usage quota
#
# ### How to make an API call
# Check this [link](https://openweathermap.org/current). We can use this API call to request the weather information from a city:
# ```https://api.openweathermap.org/data/2.5/weather?q={City}&APPID={API Key}```

# %%
import json, requests

APPID = 'YOUR_APPID_HERE'

location = input("Enter the city you want to check\n")

# TODO: Download the JSON data from OpenWeatherMap.org's API
url = 'https://api.openweathermap.org/data/2.5/weather?q={}&APPID={}'.format(location, APPID)
############### YOUR CODE STARTS HERE ###############
# 1. fetch a webpage
response =
# 2. detect the HTTP response error if it occurs

################ YOUR CODE ENDS HERE ################

############### YOUR CODE STARTS HERE ###############
# TODO: Load JSON data into a Python variable
weather_data =

################ YOUR CODE ENDS HERE ################
# print weather descriptions
w = weather_data['main']
print('Current weather in {}: \nTemperature is (Unit: Kelvin) {} - Feels like (Unit: Kelvin) {}\n'.format(location, w['temp'], w['feels_like']))
# can you print out other weather informations (like rain/snow/clouds weather parameters)?

############### YOUR CODE STARTS HERE ###############
# TODO: Save JSON data into a JSON file. You can click on `File` directory on the left menu navigation, and click on Refresh icon to see the saved JSON file.


################ YOUR CODE ENDS HERE ################

# %% [markdown]
# ## Remove the Header from a CSV File
# Write a Python program to do the following:
# - Read content from one CSV file.
# - Write out the contents, skipping the first line, to a new CSV file.
# - Note: the new CSV file should use **tab** character to separate the items each row.

# %%
import csv
csv_data = []
with open('data.csv', 'r') as f_in: # Note: you need to upload data.csv on to Colab
  ############### YOUR CODE STARTS HERE ###############
  # read content from one CSV file, skipping the first line
  # hint: you don't have to finish processing with only one line of code
  csv_reader =

  ################ YOUR CODE ENDS HERE ################
with open('data_nohead.csv','w') as f_out:
  ############### YOUR CODE STARTS HERE ###############
  # write out the content, note to use tab character to separate the items each row
  csv_writer =

  ################ YOUR CODE ENDS HERE ################
  for row in csv_data:
    csv_writer.writerow(row) # note: the last two lines are equivalet to csv_writer.writerows(csv_data)

# %% [markdown]
# Great! Now you can click on the Refresh icon in the Files panel to see the generated `data_nohead.csv` file.
